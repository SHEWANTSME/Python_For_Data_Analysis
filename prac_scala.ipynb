// %%
// main 함수를 생성 app을 상속하여 실행하는 방법
object Helloworld_proj{
    def main(args: Array[String]): Unit = {
        println("Hello, world!")
    }
}
// Out:
// defined object Helloworld_proj

// %%
object S_01_Helloworld extends App{
    println("Hello, world!")
}
// Out:
// defined object S_01_Helloworld

// %%
val s1 = 1
val s2 =2
val s3 = "Hellio"
println(s1==s2)
// Out:
// false
// s1: Int = 1
// s2: Int = 2
// s3: String = Hellio

// %%
val name = "David"
print("hi")
// Out:
// hi
// name: String = David

// %%
// you can use lambda function as well
def exec(f:(Int, Int) => Int, a: Int, b: Int) = f(a, b)
exec((a,b)=>a+b,1,2)
// you have to use 'Int' not 'int'
// Out:
// exec: (f: (Int, Int) => Int, a: Int, b: Int)Int
// res1: Int = 3
// 24/03/11 17:59:06 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 506643 ms exceeds timeout 120000 ms
// 24/03/11 17:59:06 WARN SparkContext: Killing executors is not supported by current scheduler.
// 24/03/11 17:59:08 ERROR Inbox: Ignoring error
// org.apache.spark.SparkException: Exception thrown in awaitResult:
// 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:301)
// 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
// 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
// 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
// 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
// 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
// ...

// %%
val x = 3
val y = 4
val z = 5
print(x+y+z)
// Out:
// 12
// x: Int = 3
// y: Int = 4
// z: Int = 5

// %%
class Complex(real : Double , imaginary : Double){
    def re() = real;
    def im() = imaginary;
}
object complexNumbers{
    def main(args: Array[String]): Unit = {
        val x = new Complex(1.2, 3.4)
        println("Real part: "+ x.re())
    }
}
// Out:
// defined class Complex
// defined object complexNumbers
// 24/03/19 20:32:20 ERROR Inbox: Ignoring error
// org.apache.spark.SparkException: Exception thrown in awaitResult:
// 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:301)
// 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
// 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
// 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
// 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
// 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
// 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
// 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:593)
// ...
